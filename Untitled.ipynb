# %%
import networkx
import json
import networkx as nx

state = 34
with open("../vtd-adjacency-graphs-master/vtd-adjacency-graphs/"+str(state)+"/rook.json") as f:
    data = json.load(f)

graph = nx.readwrite.json_graph.adjacency_graph(data)

import glob
import pandas as pd

allFiles = glob.glob("../zach_graphs/spatial_indexes/"+str(state)+"_*_idx.txt")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=None)
    list_.append(df)
frame = pd.concat(list_)

df = frame.rename(index=str, columns={0 : "GEOID", 1: "xaxis", 2:"yaxis"})
pos = df.set_index('GEOID').T.to_dict('list')
pos = {str(i) : (pos[i][0], pos[i][1]) for i in pos.keys()}

for node in graph.nodes():
    graph.nodes[node]["geopos"] = pos[node]

# %%
nx.draw(graph, pos = pos)

# %%
nx.is_connected(graph)
# Out:
# True

# %%
from main import explore_random

explore_random(graph, 1, 8, pictures = True, divide_and_conquer=True)
# Out:
# Code the sampling + tree walk to find equi-partitionable trees...
# 1 waiting time: 38
# 1 waiting time: 2
# 1 waiting time: 1
# 1 waiting time: 1
# 1 waiting time: 1
# 1 waiting time: 1
# 1 waiting time: 1
# [817, 816, 770, 769, 790, 807, 785, 790]
# [[<networkx.classes.graphviews.SubGraph at 0x7fbbe76454a8>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b8748>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b8208>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b8128>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b86d8>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b84a8>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b80f0>,
#   <networkx.classes.graphviews.SubGraph at 0x7fbbaa6b8ef0>]]
